# %% [markdown]
# # Env Setting

# %%
model_saved_name="model_colab.ckpt"
dataset_path="data/std_dataset"

# %%
import os
current_path = os.getcwd()
index = current_path.find("DeepLearning")
current_path = current_path[index:]
current_path='/content/drive/MyDrive/'+current_path
current_path=current_path.replace('\\','/')
"colab_dir = "+current_path
current_path
# Out:
# '/content/drive/MyDrive/t'

# %% [markdown]
# ## Colab

# %%
colab_dir = '/content/drive/MyDrive/DeepLearning/MagNet_Single_comb/MagNet_comb_3F4_cycle'  # example for colab

platform = 'auto' # auto detect platform (colab, windows_local, linux_local, unknown)
#platform = 'colab'
#platform = 'windows_local'
#platform = 'linux_local'
#platform = 'unknown'

# %% [markdown]
# ### Path config

# %%
import os

try:
    from google.colab import drive
    drive.mount("/content/drive")
except ImportError:
    if os.path.exists('c:/'):  # check if it is windows
        platform = 'windows_local'
    elif os.path.exists('/home/'):  # check if it is linux
        platform = 'linux_local'
    else:
        platform = 'unknown'
else:
    platform = 'colab'

if platform == 'colab':
  os.chdir(colab_dir)

print('\ncurrent execution path: ', os.getcwd())  #获取当前工作目录路径
print('\ncurrent platform: ', platform)  #获取当前工作目录路径
# Out:
# Mounted at /content/drive
#
# current execution path:  /content/drive/MyDrive/DeepLearning/MagNet_Single_comb/MagNet_comb_3F4_cycle
#
# current platform:  colab

# %% [markdown]
# # Cuda check

# %%
import torch

gpu_num = 0
cuda_ready = False

if torch.cuda.is_available():
    cuda_ready = True
    print('cuda good!')
    gpu_num = torch.cuda.device_count()
    if (gpu_num < 1):
        print('GPU unavailable')
    else:
        print('GPU num: ', gpu_num)  # 查看GPU数量
        for gpu in range(gpu_num):
            print('GPU type: ', torch.cuda.get_device_name(gpu))  # 查看GPU名称
            print('GPU memory: {:.2f} Gbyte'.format(
                torch.cuda.get_device_properties(gpu).total_memory /
                1e9))  # 查看GPU总内存
else:
    cuda_ready = False
    print('cuda unavailable!')
# Out:
# cuda good!
# GPU num:  1
# GPU type:  NVIDIA A100-SXM4-40GB
# GPU memory: 42.48 Gbyte

# %% [markdown]
# # Start coding

# %%
print(platform)
print(os.getcwd())
print(cuda_ready)
print(os.path.abspath(''))
# Out:
# colab
# /content/drive/MyDrive/DeepLearning/MagNet_Single_comb/MagNet_comb_3F4_cycle
# True
# /content/drive/MyDrive/DeepLearning/MagNet_Single_comb/MagNet_comb_3F4_cycle

# %%
import numpy as np
import torch
import torch.optim as optim
import torch.nn as nn
import matplotlib.pyplot as plt


import NW_LSTM
import NN_DataLoader

# %%
# Check if CUDA is available and if so, set the device to GPU
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
#device = torch.device("cpu")
print("Device using ",device)

# Instantiate the model with appropriate dimensions
model = model = NW_LSTM.get_global_model().to(device)

# Print the model architecture and parameters number
print(model)
print("Total number of parameters: ", sum(p.numel() for p in model.parameters()))

# Load the pre-train model if it exists
try:
    model.load_state_dict(torch.load(model_saved_name))
    print("Pre-train model loaded")
except:
    print("No model found, start training from scratch")
    pass

# Define the loss function and optimizer
#loss_fn = nn.MSELoss()
loss_fn = NW_LSTM.RelativeLoss()
#loss_fn = NW_LSTM.RelativeLoss_abs()
optimizer = optim.AdamW(model.parameters(), lr=2e-4)

scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=100, eta_min=0, last_epoch=-1)
# Out:
# Device using  cuda
# LSTMSeq2One(
#   (lstm): LSTM(1, 30, num_layers=3, batch_first=True)
#   (fc1): Linear(in_features=32, out_features=128, bias=True)
#   (fc2): Linear(in_features=128, out_features=196, bias=True)
#   (fc3): Linear(in_features=196, out_features=128, bias=True)
#   (fc4): Linear(in_features=128, out_features=96, bias=True)
#   (fc5): Linear(in_features=96, out_features=32, bias=True)
#   (fc6): Linear(in_features=32, out_features=32, bias=True)
#   (fc7): Linear(in_features=32, out_features=16, bias=True)
#   (fc8): Linear(in_features=16, out_features=1, bias=True)
#   (relu): ReLU()
#   (leaky_relu): LeakyReLU(negative_slope=0.01)
#   (elu): ELU(alpha=1.0)
#   (sigmoid): Sigmoid()
# )
# Total number of parameters:  90653
# Pre-train model loaded

# %%
# Default para in desktop env
epochs = 10
valid_batch_size=1000

if platform == "colab":
  epochs = 700
  valid_batch_size=2000


train_dataloader = NN_DataLoader.get_dataLoader(os.path.normpath(dataset_path +
                                                            "/train.mat"),
                                          batch_size=128)

# Get validation data
valid_dataloader = NN_DataLoader.get_dataLoader(os.path.normpath(dataset_path +
                                                            "/valid.mat"),
                                            batch_size=valid_batch_size)
valid_inputs, valid_targets = next(iter(valid_dataloader))
valid_inputs, valid_targets = valid_inputs.to(device), valid_targets.to(device)



# estimate time used for training
import time
t0 = time.perf_counter()

# Save the model with the lowest validation loss
with torch.no_grad():
    valid_outputs = model(valid_inputs)
    # Compute loss
    minium_loss = loss_fn(valid_outputs, valid_targets)

# Train the model
for epoch in range(epochs):

    # estimate time used for one epoch(s)
    t_epoch = time.perf_counter() - t0
    t0 = time.perf_counter()

    # Train one epoch
    for i, (train_inputs, train_targets) in enumerate(train_dataloader):
        # Move data to device
        train_inputs, train_targets = train_inputs.to(device), train_targets.to(device)

        # Forward pass
        train_outputs = model(train_inputs)

        # Compute loss
        loss = loss_fn(train_outputs, train_targets)

        # Backward pass and optimize
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

    # Compute validation loss
    if epoch > 0:
        with torch.no_grad():
            valid_outputs = model(valid_inputs)
            # Compute loss
            valid_loss = loss_fn(valid_outputs, valid_targets)

        if valid_loss < minium_loss:
            minium_loss = valid_loss
            torch.save(model.state_dict(), model_saved_name)
            print(f"  Model saved , Validation Loss: {valid_loss.item():.3e}, lr: {optimizer.param_groups[0]['lr']:.3e}")

    # update lr
    scheduler.step()


    # Print loss every 10 epochs
    if (epoch + 1) % 10 == 0:
        print(f"Epoch {epoch + 1}/{epochs}, Training Loss: {loss.item():.3e}, "
            #   f"Validation Loss: {valid_loss.item():.3e} ,"
              f"Remain time: {t_epoch/60 * (epochs - epoch - 1):.1f} min")
# Out:
#   Model saved , Validation Loss: 1.935e-02, lr: 2.000e-04
#   Model saved , Validation Loss: 1.136e-02, lr: 1.998e-04
#   Model saved , Validation Loss: 7.994e-03, lr: 1.996e-04
#   Model saved , Validation Loss: 6.530e-03, lr: 1.992e-04
#   Model saved , Validation Loss: 5.729e-03, lr: 1.988e-04
#   Model saved , Validation Loss: 4.326e-03, lr: 1.982e-04
#   Model saved , Validation Loss: 3.703e-03, lr: 1.976e-04
#   Model saved , Validation Loss: 3.288e-03, lr: 1.969e-04
#   Model saved , Validation Loss: 2.869e-03, lr: 1.960e-04
# Epoch 10/700, Training Loss: 3.300e-03, Remain time: 2.2 min
#   Model saved , Validation Loss: 2.730e-03, lr: 1.951e-04
#   Model saved , Validation Loss: 2.700e-03, lr: 1.941e-04
#   Model saved , Validation Loss: 2.185e-03, lr: 1.930e-04
#   Model saved , Validation Loss: 1.915e-03, lr: 1.905e-04
#   Model saved , Validation Loss: 1.891e-03, lr: 1.891e-04
#   Model saved , Validation Loss: 1.770e-03, lr: 1.876e-04
#   Model saved , Validation Loss: 1.637e-03, lr: 1.844e-04
#   Model saved , Validation Loss: 1.614e-03, lr: 1.827e-04
# Epoch 20/700, Training Loss: 1.370e-03, Remain time: 2.1 min
#   Model saved , Validation Loss: 1.533e-03, lr: 1.809e-04
#   Model saved , Validation Loss: 1.517e-03, lr: 1.790e-04
#   Model saved , Validation Loss: 1.455e-03, lr: 1.750e-04
#   Model saved , Validation Loss: 1.386e-03, lr: 1.729e-04
#   Model saved , Validation Loss: 1.340e-03, lr: 1.685e-04
#   Model saved , Validation Loss: 1.264e-03, lr: 1.613e-04
# Epoch 30/700, Training Loss: 9.155e-04, Remain time: 2.1 min
#   Model saved , Validation Loss: 1.239e-03, lr: 1.588e-04
#   Model saved , Validation Loss: 1.166e-03, lr: 1.536e-04
#   Model saved , Validation Loss: 1.135e-03, lr: 1.339e-04
# Epoch 40/700, Training Loss: 1.025e-03, Remain time: 2.0 min
#   Model saved , Validation Loss: 1.097e-03, lr: 1.279e-04
#   Model saved , Validation Loss: 1.088e-03, lr: 1.218e-04
#   Model saved , Validation Loss: 1.036e-03, lr: 1.187e-04
#   Model saved , Validation Loss: 9.912e-04, lr: 1.031e-04
# Epoch 50/700, Training Loss: 1.362e-03, Remain time: 2.0 min
#   Model saved , Validation Loss: 9.733e-04, lr: 9.059e-05
#   Model saved , Validation Loss: 9.714e-04, lr: 8.747e-05
#   Model saved , Validation Loss: 9.437e-04, lr: 7.513e-05
# Epoch 60/700, Training Loss: 7.290e-04, Remain time: 2.0 min
#   Model saved , Validation Loss: 9.277e-04, lr: 6.910e-05
#   Model saved , Validation Loss: 9.173e-04, lr: 4.910e-05
# Epoch 70/700, Training Loss: 7.230e-04, Remain time: 2.0 min
#   Model saved , Validation Loss: 8.871e-04, lr: 3.626e-05
#   Model saved , Validation Loss: 8.804e-04, lr: 2.098e-05
# Epoch 80/700, Training Loss: 6.111e-04, Remain time: 1.9 min
#   Model saved , Validation Loss: 8.793e-04, lr: 1.393e-05
#   Model saved , Validation Loss: 8.770e-04, lr: 8.225e-06
#   Model saved , Validation Loss: 8.757e-04, lr: 7.022e-06
# Epoch 90/700, Training Loss: 4.709e-04, Remain time: 1.9 min
#   Model saved , Validation Loss: 8.756e-04, lr: 1.771e-06
# Epoch 100/700, Training Loss: 8.574e-04, Remain time: 1.8 min
#   Model saved , Validation Loss: 8.756e-04, lr: 7.885e-07
#   Model saved , Validation Loss: 8.737e-04, lr: 1.771e-06
#   Model saved , Validation Loss: 8.729e-04, lr: 3.971e-06
# Epoch 110/700, Training Loss: 8.525e-04, Remain time: 1.8 min
#   Model saved , Validation Loss: 8.661e-04, lr: 1.237e-05
# Epoch 120/700, Training Loss: 8.812e-04, Remain time: 1.9 min
#   Model saved , Validation Loss: 8.603e-04, lr: 3.155e-05
# Epoch 130/700, Training Loss: 6.247e-04, Remain time: 1.8 min
#   Model saved , Validation Loss: 8.497e-04, lr: 4.642e-05
#   Model saved , Validation Loss: 8.475e-04, lr: 5.742e-05
# Epoch 140/700, Training Loss: 8.047e-04, Remain time: 1.8 min
#   Model saved , Validation Loss: 8.349e-04, lr: 7.210e-05
#   Model saved , Validation Loss: 8.301e-04, lr: 8.126e-05
#   Model saved , Validation Loss: 8.185e-04, lr: 9.372e-05
#   Model saved , Validation Loss: 8.092e-04, lr: 9.686e-05
# Epoch 150/700, Training Loss: 8.793e-04, Remain time: 1.8 min
#   Model saved , Validation Loss: 7.846e-04, lr: 1.218e-04
# Epoch 160/700, Training Loss: 6.360e-04, Remain time: 1.7 min
#   Model saved , Validation Loss: 7.645e-04, lr: 1.397e-04
# Epoch 170/700, Training Loss: 5.177e-04, Remain time: 1.6 min
#   Model saved , Validation Loss: 7.275e-04, lr: 1.613e-04
# Epoch 180/700, Training Loss: 8.982e-04, Remain time: 1.7 min
#   Model saved , Validation Loss: 7.155e-04, lr: 1.861e-04
# Epoch 190/700, Training Loss: 7.349e-04, Remain time: 1.6 min
#   Model saved , Validation Loss: 7.072e-04, lr: 1.998e-04
# Epoch 200/700, Training Loss: 5.150e-04, Remain time: 1.6 min
#   Model saved , Validation Loss: 6.834e-04, lr: 1.992e-04
#   Model saved , Validation Loss: 6.583e-04, lr: 1.988e-04
# Epoch 210/700, Training Loss: 5.159e-04, Remain time: 1.5 min
# Epoch 220/700, Training Loss: 6.349e-04, Remain time: 1.5 min
# Epoch 230/700, Training Loss: 4.873e-04, Remain time: 1.4 min
#   Model saved , Validation Loss: 6.578e-04, lr: 1.562e-04
#   Model saved , Validation Loss: 6.557e-04, lr: 1.536e-04
#   Model saved , Validation Loss: 6.532e-04, lr: 1.397e-04
#   Model saved , Validation Loss: 6.272e-04, lr: 1.339e-04
# Epoch 240/700, Training Loss: 4.555e-04, Remain time: 1.4 min
# Epoch 250/700, Training Loss: 3.292e-04, Remain time: 1.4 min
#   Model saved , Validation Loss: 6.226e-04, lr: 9.686e-05
#   Model saved , Validation Loss: 6.154e-04, lr: 8.126e-05
#   Model saved , Validation Loss: 6.078e-04, lr: 7.819e-05
#   Model saved , Validation Loss: 5.919e-04, lr: 7.210e-05
# Epoch 260/700, Training Loss: 2.877e-04, Remain time: 1.4 min
# Epoch 270/700, Training Loss: 4.051e-04, Remain time: 1.4 min
# Epoch 280/700, Training Loss: 3.770e-04, Remain time: 1.3 min
# Epoch 290/700, Training Loss: 3.392e-04, Remain time: 1.3 min
# Epoch 300/700, Training Loss: 4.464e-04, Remain time: 1.2 min
# Epoch 310/700, Training Loss: 3.853e-04, Remain time: 1.2 min
# Epoch 320/700, Training Loss: 3.301e-04, Remain time: 1.1 min
#   Model saved , Validation Loss: 5.911e-04, lr: 2.499e-05
# Epoch 330/700, Training Loss: 5.023e-04, Remain time: 1.1 min
# Epoch 340/700, Training Loss: 5.018e-04, Remain time: 1.1 min
# Epoch 350/700, Training Loss: 4.826e-04, Remain time: 1.1 min
# Epoch 360/700, Training Loss: 1.202e-03, Remain time: 1.0 min
# Epoch 370/700, Training Loss: 5.406e-04, Remain time: 1.0 min
# Epoch 380/700, Training Loss: 4.691e-04, Remain time: 1.0 min
#   Model saved , Validation Loss: 5.740e-04, lr: 1.827e-04
# Epoch 390/700, Training Loss: 9.583e-04, Remain time: 1.2 min
#   Model saved , Validation Loss: 5.651e-04, lr: 1.969e-04
# Epoch 400/700, Training Loss: 5.809e-04, Remain time: 0.9 min
# Epoch 410/700, Training Loss: 3.823e-04, Remain time: 0.9 min
# Epoch 420/700, Training Loss: 3.668e-04, Remain time: 0.9 min
#   Model saved , Validation Loss: 5.608e-04, lr: 1.707e-04
# Epoch 430/700, Training Loss: 3.788e-04, Remain time: 0.8 min
#   Model saved , Validation Loss: 5.586e-04, lr: 1.454e-04
# Epoch 440/700, Training Loss: 3.575e-04, Remain time: 0.8 min
#   Model saved , Validation Loss: 5.508e-04, lr: 1.249e-04
#   Model saved , Validation Loss: 5.466e-04, lr: 1.218e-04
# Epoch 450/700, Training Loss: 2.864e-04, Remain time: 0.8 min
#   Model saved , Validation Loss: 5.446e-04, lr: 7.819e-05
# Epoch 460/700, Training Loss: 2.418e-04, Remain time: 0.7 min
#   Model saved , Validation Loss: 5.446e-04, lr: 6.613e-05
#   Model saved , Validation Loss: 5.404e-04, lr: 6.319e-05
#   Model saved , Validation Loss: 5.359e-04, lr: 4.642e-05
# Epoch 470/700, Training Loss: 4.310e-04, Remain time: 0.7 min
#   Model saved , Validation Loss: 5.355e-04, lr: 2.098e-05
# Epoch 480/700, Training Loss: 3.328e-04, Remain time: 0.7 min
#   Model saved , Validation Loss: 5.351e-04, lr: 1.729e-05
#   Model saved , Validation Loss: 5.350e-04, lr: 8.225e-06
# Epoch 490/700, Training Loss: 3.384e-04, Remain time: 0.6 min
#   Model saved , Validation Loss: 5.331e-04, lr: 4.894e-06
# Epoch 500/700, Training Loss: 1.990e-04, Remain time: 0.6 min
# Epoch 510/700, Training Loss: 2.634e-04, Remain time: 0.6 min
# Epoch 520/700, Training Loss: 3.641e-04, Remain time: 0.5 min
#   Model saved , Validation Loss: 5.311e-04, lr: 2.710e-05
# Epoch 530/700, Training Loss: 4.474e-04, Remain time: 0.5 min
# Epoch 540/700, Training Loss: 5.289e-04, Remain time: 0.5 min
# Epoch 550/700, Training Loss: 4.410e-04, Remain time: 0.5 min
# Epoch 560/700, Training Loss: 4.785e-04, Remain time: 0.4 min
# Epoch 570/700, Training Loss: 5.218e-04, Remain time: 0.4 min
# Epoch 580/700, Training Loss: 2.470e-04, Remain time: 0.4 min
# Epoch 590/700, Training Loss: 4.987e-04, Remain time: 0.3 min
# Epoch 600/700, Training Loss: 9.102e-04, Remain time: 0.3 min
# Epoch 610/700, Training Loss: 5.843e-04, Remain time: 0.3 min
# Epoch 620/700, Training Loss: 5.879e-04, Remain time: 0.2 min
# Epoch 630/700, Training Loss: 2.915e-04, Remain time: 0.2 min
#   Model saved , Validation Loss: 5.240e-04, lr: 1.588e-04
#   Model saved , Validation Loss: 5.191e-04, lr: 1.339e-04
# Epoch 640/700, Training Loss: 3.296e-04, Remain time: 0.2 min
#   Model saved , Validation Loss: 5.177e-04, lr: 1.249e-04
# Epoch 650/700, Training Loss: 3.612e-04, Remain time: 0.2 min
#   Model saved , Validation Loss: 5.170e-04, lr: 7.210e-05
# Epoch 660/700, Training Loss: 3.157e-04, Remain time: 0.1 min
#   Model saved , Validation Loss: 5.133e-04, lr: 6.910e-05
# Epoch 670/700, Training Loss: 2.181e-04, Remain time: 0.1 min
#   Model saved , Validation Loss: 5.107e-04, lr: 2.499e-05
#   Model saved , Validation Loss: 5.098e-04, lr: 2.295e-05
# Epoch 680/700, Training Loss: 2.825e-04, Remain time: 0.1 min
#   Model saved , Validation Loss: 5.097e-04, lr: 1.729e-05
#   Model saved , Validation Loss: 5.094e-04, lr: 1.237e-05
#   Model saved , Validation Loss: 5.087e-04, lr: 9.517e-06
#   Model saved , Validation Loss: 5.085e-04, lr: 5.912e-06
# Epoch 690/700, Training Loss: 2.120e-04, Remain time: 0.0 min
#   Model saved , Validation Loss: 5.084e-04, lr: 3.971e-06
# Epoch 700/700, Training Loss: 3.637e-04, Remain time: 0.0 min

# %% [markdown]
# ## GPU monitor
# ### nvidia-smi -l 3

# %% [markdown]
# # Env Setting

# %%
model_saved_name="model_colab.ckpt"
dataset_path="data/std_dataset"

# %% [markdown]
# ## Colab

# %%
colab_dir = '/content/drive/MyDrive/DeepLearning/MagNet_lstm_3C90_cycle_10_6'  # example for colab

platform = 'auto' # auto detect platform (colab, windows_local, linux_local, unknown)
#platform = 'colab'
#platform = 'windows_local'
#platform = 'linux_local'
#platform = 'unknown'

# %% [markdown]
# ### Path config

# %%
import os

try:
    from google.colab import drive
    drive.mount("/content/drive")
except ImportError:
    if os.path.exists('c:/'):  # check if it is windows
        platform = 'windows_local'
    elif os.path.exists('/home/'):  # check if it is linux
        platform = 'linux_local'
    else:
        platform = 'unknown'
else:
    platform = 'colab'

if platform == 'colab':
  os.chdir(colab_dir)

print('\ncurrent execution path: ', os.getcwd())  #获取当前工作目录路径
print('\ncurrent platform: ', platform)  #获取当前工作目录路径
# Out:
# Mounted at /content/drive
#
# current execution path:  /content/drive/MyDrive/DeepLearning/MagNet_lstm_3C90_cycle_10_6
#
# current platform:  colab

# %% [markdown]
# # Cuda check

# %%
import torch

gpu_num = 0
cuda_ready = False

if torch.cuda.is_available():
    cuda_ready = True
    print('cuda good!')
    gpu_num = torch.cuda.device_count()
    if (gpu_num < 1):
        print('GPU unavailable')
    else:
        print('GPU num: ', gpu_num)  # 查看GPU数量
        for gpu in range(gpu_num):
            print('GPU type: ', torch.cuda.get_device_name(gpu))  # 查看GPU名称
            print('GPU memory: {:.2f} Gbyte'.format(
                torch.cuda.get_device_properties(gpu).total_memory /
                1e9))  # 查看GPU总内存
else:
    cuda_ready = False
    print('cuda unavailable!')
# Out:
# cuda good!
# GPU num:  1
# GPU type:  NVIDIA A100-SXM4-40GB
# GPU memory: 42.48 Gbyte

# %% [markdown]
# # Start coding

# %%
print(platform)
print(os.getcwd())
print(cuda_ready)
print(os.path.abspath(''))
# Out:
# colab
# /content/drive/MyDrive/DeepLearning/MagNet_lstm_3C90_cycle_10_6
# True
# /content/drive/MyDrive/DeepLearning/MagNet_lstm_3C90_cycle_10_6

# %%
import numpy as np
import torch
import torch.optim as optim
import torch.nn as nn
import matplotlib.pyplot as plt


import NW_LSTM
import NN_DataLoader

# %%
# Check if CUDA is available and if so, set the device to GPU
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
#device = torch.device("cpu")
print("Device using ",device)

# Instantiate the model with appropriate dimensions
model = model = NW_LSTM.get_global_model().to(device)

# Print the model architecture and parameters number
print(model)
print("Total number of parameters: ", sum(p.numel() for p in model.parameters()))

# Load the pre-train model if it exists
try:
    model.load_state_dict(torch.load(model_saved_name))
    print("Pre-train model loaded")
except:
    print("No model found, start training from scratch")
    pass

# Define the loss function and optimizer
#loss_fn = nn.MSELoss()
#loss_fn = NW_LSTM.RelativeLoss()
loss_fn = NW_LSTM.RelativeLoss_abs()
optimizer = optim.Adam(model.parameters(), lr=1e-3)
# Out:
# Device using  cuda
# LSTMSeq2One(
#   (lstm): LSTM(3, 30, batch_first=True)
#   (fc1): Linear(in_features=30, out_features=64, bias=True)
#   (fc2): Linear(in_features=64, out_features=32, bias=True)
#   (fc3): Linear(in_features=32, out_features=16, bias=True)
#   (fc4): Linear(in_features=16, out_features=8, bias=True)
#   (fc5): Linear(in_features=8, out_features=8, bias=True)
#   (fc6): Linear(in_features=8, out_features=1, bias=True)
#   (relu): ReLU()
#   (leaky_relu): LeakyReLU(negative_slope=0.01)
#   (elu): ELU(alpha=1.0)
# )
# Total number of parameters:  9009
# No model found, start training from scratch

# %%
# Default para in desktop env
epochs = 10
valid_batch_size=1000

if platform == "colab":
  epochs = 700
  valid_batch_size=2000


train_dataloader = NN_DataLoader.get_dataLoader(os.path.normpath(dataset_path +
                                                            "/train.mat"),
                                          batch_size=128)

# Get validation data
valid_dataloader = NN_DataLoader.get_dataLoader(os.path.normpath(dataset_path +
                                                            "/valid.mat"),
                                            batch_size=valid_batch_size)
valid_inputs, valid_targets = next(iter(valid_dataloader))
valid_inputs, valid_targets = valid_inputs.to(device), valid_targets.to(device)

# Save the model with the lowest validation loss
minium_loss = 1

# estimate time used for training
import time
t0 = time.perf_counter()

# Train the model
for epoch in range(epochs):

    # estimate time used for one epoch(s)
    t_epoch = time.perf_counter() - t0
    t0 = time.perf_counter()

    # Train one epoch
    for i, (train_inputs, train_targets) in enumerate(train_dataloader):
        # Move data to device
        train_inputs, train_targets = train_inputs.to(device), train_targets.to(device)

        # Forward pass
        train_outputs = model(train_inputs)

        # Compute loss
        loss = loss_fn(train_outputs, train_targets)

        # Backward pass and optimize
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

    # Compute validation loss
    if epoch > 300:
        with torch.no_grad():
            valid_outputs = model(valid_inputs)
            # Compute loss
            valid_loss = loss_fn(valid_outputs, valid_targets)

        if valid_loss < minium_loss:
            minium_loss = valid_loss
            torch.save(model.state_dict(), model_saved_name)
            print(f"  Model saved , Validation Loss: {valid_loss.item():.3e}, ")

    # Print loss every 10 epochs
    if (epoch + 1) % 10 == 0:
        print(f"Epoch {epoch + 1}/{epochs}, Training Loss: {loss.item():.3e}, "
            #   f"Validation Loss: {valid_loss.item():.3e} ,"
              f"Remain time: {t_epoch/60 * (epochs - epoch - 1):.1f} min")
# Out:
# Epoch 10/700, Training Loss: 5.569e-01, Remain time: 10.0 min
# Epoch 20/700, Training Loss: 2.036e-01, Remain time: 9.4 min
# Epoch 30/700, Training Loss: 3.030e-01, Remain time: 9.6 min
# Epoch 40/700, Training Loss: 3.617e-01, Remain time: 9.2 min
# Epoch 50/700, Training Loss: 1.267e-01, Remain time: 9.0 min
# Epoch 60/700, Training Loss: 3.810e-01, Remain time: 9.1 min
# Epoch 70/700, Training Loss: 1.366e-01, Remain time: 8.9 min
# Epoch 80/700, Training Loss: 1.301e-01, Remain time: 8.7 min
# Epoch 90/700, Training Loss: 1.963e-01, Remain time: 8.6 min
# Epoch 100/700, Training Loss: 8.413e-02, Remain time: 8.5 min
# Epoch 110/700, Training Loss: 6.386e-02, Remain time: 8.4 min
# Epoch 120/700, Training Loss: 1.279e-01, Remain time: 8.1 min
# Epoch 130/700, Training Loss: 5.609e-02, Remain time: 7.9 min
# Epoch 140/700, Training Loss: 8.806e-02, Remain time: 7.9 min
# Epoch 150/700, Training Loss: 9.087e-02, Remain time: 7.8 min
# Epoch 160/700, Training Loss: 9.178e-02, Remain time: 7.6 min
# Epoch 170/700, Training Loss: 1.044e-01, Remain time: 7.4 min
# Epoch 180/700, Training Loss: 1.373e-01, Remain time: 7.4 min
# Epoch 190/700, Training Loss: 1.399e-01, Remain time: 7.3 min
# Epoch 200/700, Training Loss: 4.973e-02, Remain time: 7.1 min
# Epoch 210/700, Training Loss: 4.494e-02, Remain time: 7.0 min
# Epoch 220/700, Training Loss: 4.434e-02, Remain time: 6.9 min
# Epoch 230/700, Training Loss: 6.064e-02, Remain time: 6.7 min
# Epoch 240/700, Training Loss: 5.362e-02, Remain time: 6.6 min
# Epoch 250/700, Training Loss: 6.430e-02, Remain time: 6.3 min
# Epoch 260/700, Training Loss: 2.452e-02, Remain time: 6.2 min
# Epoch 270/700, Training Loss: 3.533e-02, Remain time: 6.1 min
# Epoch 280/700, Training Loss: 4.257e-02, Remain time: 5.9 min
# Epoch 290/700, Training Loss: 1.203e-01, Remain time: 6.0 min
# Epoch 300/700, Training Loss: 8.703e-02, Remain time: 5.6 min
#   Model saved , Validation Loss: 3.490e-02,
# Epoch 310/700, Training Loss: 4.538e-02, Remain time: 5.5 min
#   Model saved , Validation Loss: 3.290e-02,
#   Model saved , Validation Loss: 3.098e-02,
# Epoch 320/700, Training Loss: 3.202e-02, Remain time: 5.5 min
# Epoch 330/700, Training Loss: 8.046e-02, Remain time: 5.2 min
# Epoch 340/700, Training Loss: 5.877e-02, Remain time: 5.1 min
# Epoch 350/700, Training Loss: 5.940e-02, Remain time: 4.9 min
# Epoch 360/700, Training Loss: 6.628e-02, Remain time: 4.8 min
#   Model saved , Validation Loss: 2.580e-02,
# Epoch 370/700, Training Loss: 1.395e-01, Remain time: 4.7 min
# Epoch 380/700, Training Loss: 7.117e-02, Remain time: 4.5 min
#   Model saved , Validation Loss: 2.517e-02,
# Epoch 390/700, Training Loss: 7.508e-02, Remain time: 4.4 min
# Epoch 400/700, Training Loss: 2.822e-02, Remain time: 4.3 min
# Epoch 410/700, Training Loss: 6.804e-02, Remain time: 4.1 min
# Epoch 420/700, Training Loss: 7.594e-02, Remain time: 4.0 min
#   Model saved , Validation Loss: 2.517e-02,
# Epoch 430/700, Training Loss: 3.919e-02, Remain time: 3.8 min
# Epoch 440/700, Training Loss: 5.497e-02, Remain time: 3.6 min
# Epoch 450/700, Training Loss: 4.454e-02, Remain time: 3.6 min
#   Model saved , Validation Loss: 2.391e-02,
# Epoch 460/700, Training Loss: 4.892e-02, Remain time: 3.4 min
# Epoch 470/700, Training Loss: 4.254e-02, Remain time: 3.2 min
# Epoch 480/700, Training Loss: 4.198e-02, Remain time: 3.2 min
#   Model saved , Validation Loss: 2.258e-02,
# Epoch 490/700, Training Loss: 2.540e-02, Remain time: 3.0 min
# Epoch 500/700, Training Loss: 4.614e-02, Remain time: 2.9 min
# Epoch 510/700, Training Loss: 3.003e-02, Remain time: 2.7 min
# Epoch 520/700, Training Loss: 5.308e-02, Remain time: 2.5 min
# Epoch 530/700, Training Loss: 2.402e-02, Remain time: 2.4 min
# Epoch 540/700, Training Loss: 8.197e-02, Remain time: 2.3 min
# Epoch 550/700, Training Loss: 1.161e-01, Remain time: 2.1 min
# Epoch 560/700, Training Loss: 3.393e-02, Remain time: 1.9 min
# Epoch 570/700, Training Loss: 4.960e-02, Remain time: 1.8 min
# Epoch 580/700, Training Loss: 6.548e-02, Remain time: 1.7 min
#   Model saved , Validation Loss: 2.123e-02,
# Epoch 590/700, Training Loss: 4.391e-02, Remain time: 1.6 min
# Epoch 600/700, Training Loss: 4.730e-02, Remain time: 1.4 min
# Epoch 610/700, Training Loss: 2.009e-01, Remain time: 1.3 min
# Epoch 620/700, Training Loss: 2.042e-02, Remain time: 1.1 min
#   Model saved , Validation Loss: 2.098e-02,
# Epoch 630/700, Training Loss: 2.681e-02, Remain time: 1.0 min
# Epoch 640/700, Training Loss: 2.103e-02, Remain time: 0.8 min
# Epoch 650/700, Training Loss: 3.219e-02, Remain time: 0.7 min
# Epoch 660/700, Training Loss: 6.734e-02, Remain time: 0.6 min
# Epoch 670/700, Training Loss: 1.302e-01, Remain time: 0.4 min
# Epoch 680/700, Training Loss: 1.331e-01, Remain time: 0.3 min
# Epoch 690/700, Training Loss: 4.967e-02, Remain time: 0.1 min
#   Model saved , Validation Loss: 1.866e-02,
# Epoch 700/700, Training Loss: 2.811e-02, Remain time: 0.0 min

# %% [markdown]
# ## GPU monitor
# ### nvidia-smi -l 3
